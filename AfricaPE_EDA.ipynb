# %%
import pandas as pd
import os

# %%
df0 = pd.read_csv('/Users/saharlahershi/Desktop/Africa_PE/Africa_PE_Data/african-startups-2-22-2023.csv')
df1 = pd.read_csv('/Users/saharlahershi/Desktop/Africa_PE/Africa_PE_Data/african-startups-2-22-2023 (1).csv')
df2 = pd.read_csv('/Users/saharlahershi/Desktop/Africa_PE/Africa_PE_Data/african-startups-2-22-2023 (2).csv')
df3 = pd.read_csv('/Users/saharlahershi/Desktop/Africa_PE/Africa_PE_Data/african-startups-2-22-2023 (3).csv')
df4 = pd.read_csv('/Users/saharlahershi/Desktop/Africa_PE/Africa_PE_Data/african-startups-2-22-2023 (4).csv')
df5 = pd.read_csv('/Users/saharlahershi/Desktop/Africa_PE/Africa_PE_Data/african-startups-2-22-2023 (5).csv')

# %%
combined_dataset = pd.concat([df0, df1, df2, df3, df4, df5])
combined_dataset
# Out:
#                           Organization Name  \
# 0                                Prime Cure
# 1                         PanAfrican Energy
# 2                          Elisar Resources
# 3    CAFE Informatique & Télécommunications
# 4                    Concilium Technologies
# ..                                      ...
# 588         Lenana Innovative Solutions Ltd
# 589                                 Lemitar
# 590                           Mahaseel Masr
# 591                                 Malaica
# 592                         Commune Writers
#
#                                  Organization Name URL  Money Raised  \
# 0    https://www.crunchbase.com/organization/prime-...           NaN
# 1    https://www.crunchbase.com/organization/panafr...           NaN
# 2       https://www.crunchbase.com/organization/elisar     2000000.0
# 3    https://www.crunchbase.com/organization/cafe-i...           NaN
# 4    https://www.crunchbase.com/organization/concil...           NaN
# ...
